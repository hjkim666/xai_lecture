# %% [markdown]
# ## Pandas 그룹화, 병합 실습 WS

# %%
import pandas as pd

# %% [markdown]
# ### 데이터 불러오기

# %%
import zipfile

DATA_DIR = './'

with zipfile.ZipFile("./data/split_data.zip" , "r") as zip_ref:
    zip_ref.extractall(DATA_DIR)

# %% [markdown]
# ### data 폴더 내에 있는 split으로 시작하는 모든 파일 목록 가져오기

# %%
# 이 코드는 그대로 실행하세요.
import glob

# glob 모듈을 이용하여 특정 폴더 내 파일 목록을 가져올 수 있음
# 이 파일 목록을 이용하여 데이터를 읽고 각각 df으로 만든 후 리스트에 저장하는 코드
dfs = [pd.read_csv(filename) for filename in glob.glob('*split*')]

# %%
# 로드한 데이터프레임들을 위에서부터 3개만 출력하세요.
for df in dfs[:3]:
    display(df)
# Out:
#         building_id  meter            timestamp  meter_reading
# 0                 0      0  2016-01-01 00:00:00         0.0000
# 1                10      0  2016-01-01 00:00:00         0.0000
# 2                20      0  2016-01-01 00:00:00         0.0000
# 3                31      0  2016-01-01 00:00:00         0.0000
# 4                41      0  2016-01-01 00:00:00         0.0000
# ...             ...    ...                  ...            ...
# 199995          748      0  2016-02-06 06:00:00        36.0167
# 199996          756      0  2016-02-06 06:00:00        25.2167
# 199997          764      0  2016-02-06 06:00:00        26.2000
# 199998          769      0  2016-02-06 06:00:00        73.0000
# 199999          774      1  2016-02-06 06:00:00         0.0000
#
# [200000 rows x 4 columns]
#         building_id  meter            timestamp  meter_reading
# 0               780      0  2016-02-06 06:00:00       663.4330
# ...

# %%
# 로드한 모든 데이터프레임을 상하로 연결하되 인덱스를 초기화하고 df_data에 저장하세요.
# Out:
#         building_id  meter            timestamp  meter_reading
# 0                 0      0  2016-01-01 00:00:00            0.0
# 1                10      0  2016-01-01 00:00:00            0.0
# 2                20      0  2016-01-01 00:00:00            0.0
# 3                31      0  2016-01-01 00:00:00            0.0
# 4                41      0  2016-01-01 00:00:00            0.0
# ...             ...    ...                  ...            ...
# 199995          910      0  2016-07-02 19:00:00            0.0
# 199996          913      1  2016-07-02 19:00:00            0.0
# 199997          916      2  2016-07-02 19:00:00            0.0
# 199998          920      2  2016-07-02 19:00:00            0.0
# 199999          924      1  2016-07-02 19:00:00            0.0
#
# [1000000 rows x 4 columns]

# %%
# building_metadata.csv 데이터를 읽어서 df_meta에 저장하세요.
# Out:
#       site_id  building_id                    primary_use  square_feet  \
# 0           0            0                      Education         7432
# 1           0            1                      Education         2720
# 2           0            2                      Education         5376
# 3           0            3                      Education        23685
# 4           0            4                      Education       116607
# ...       ...          ...                            ...          ...
# 1444       15         1444  Entertainment/public assembly        19619
# 1445       15         1445                      Education         4298
# 1446       15         1446  Entertainment/public assembly        11265
# 1447       15         1447            Lodging/residential        29775
# 1448       15         1448                         Office        92271
#
#       year_built  floor_count
# 0         2008.0          NaN
# 1         2004.0          NaN
# ...

# %%
# df_meta의 정보를 조회하세요.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1449 entries, 0 to 1448
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   site_id      1449 non-null   int64
#  1   building_id  1449 non-null   int64
#  2   primary_use  1449 non-null   object
#  3   square_feet  1449 non-null   int64
#  4   year_built   675 non-null    float64
#  5   floor_count  355 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 68.0+ KB

# %%
# weather.csv 데이터를 읽어서 df_weather에 저장하세요.
# Out:
#         site_id            timestamp  air_temperature  cloud_coverage  \
# 0             0  2016-01-01 00:00:00             25.0             6.0
# 1             0  2016-01-01 01:00:00             24.4             NaN
# 2             0  2016-01-01 02:00:00             22.8             2.0
# 3             0  2016-01-01 03:00:00             21.1             2.0
# 4             0  2016-01-01 04:00:00             20.0             2.0
# ...         ...                  ...              ...             ...
# 139768       15  2016-12-31 19:00:00              3.0             NaN
# 139769       15  2016-12-31 20:00:00              2.8             2.0
# 139770       15  2016-12-31 21:00:00              2.8             NaN
# 139771       15  2016-12-31 22:00:00              2.2             NaN
# 139772       15  2016-12-31 23:00:00              1.7             NaN
#
#         dew_temperature  precip_depth_1_hr  sea_level_pressure  \
# ...

# %%
# df_weather의 정보를 조회하세요.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139773 entries, 0 to 139772
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   site_id             139773 non-null  int64
#  1   timestamp           139773 non-null  object
#  2   air_temperature     139718 non-null  float64
#  3   cloud_coverage      70600 non-null   float64
#  4   dew_temperature     139660 non-null  float64
#  5   precip_depth_1_hr   89484 non-null   float64
#  6   sea_level_pressure  129155 non-null  float64
#  7   wind_direction      133505 non-null  float64
#  8   wind_speed          139469 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 9.6+ MB

# %%
# df_data와 df_meta의 공통 열을 출력하세요.
# Out:
# {'building_id'}

# %%
# df_data와 df_meta를 공통 열을 기준으로 병합한 후 df_merge에 저장하세요.
# Out:
#         building_id  meter            timestamp  meter_reading  site_id  \
# 0                 0      0  2016-01-01 00:00:00           0.00        0
# 1                 0      0  2016-01-01 06:00:00           0.00        0
# 2                 0      0  2016-01-01 12:00:00           0.00        0
# 3                 0      0  2016-01-01 18:00:00           0.00        0
# 4                 0      0  2016-01-01 21:00:00           0.00        0
# ...             ...    ...                  ...            ...      ...
# 999995          555      0  2016-07-02 00:00:00          34.27        3
# 999996          555      0  2016-07-02 01:00:00          29.44        3
# 999997          555      0  2016-07-02 09:00:00          35.64        3
# 999998          555      0  2016-07-02 12:00:00          28.67        3
# 999999          555      0  2016-07-02 15:00:00          36.33        3
#
#        primary_use  square_feet  year_built  floor_count
# ...

# %%
# df_merge와 df_weather의 공통 열을 출력하세요.
# Out:
# {'site_id', 'timestamp'}

# %%
# df_merge와 df_weather를 공통 열을 기준으로 merge한 후 df에 저장하세요.
# Out:
#         building_id  meter            timestamp  meter_reading  site_id  \
# 0                 0      0  2016-01-01 00:00:00         0.0000        0
# 1                10      0  2016-01-01 00:00:00         0.0000        0
# 2                20      0  2016-01-01 00:00:00         0.0000        0
# 3                31      0  2016-01-01 00:00:00         0.0000        0
# 4                41      0  2016-01-01 00:00:00         0.0000        0
# ...             ...    ...                  ...            ...      ...
# 994529         1051      0  2016-07-02 01:00:00        12.6150       12
# 994530         1061      0  2016-07-02 01:00:00        28.0125       12
# 994531         1041      0  2016-07-02 06:00:00         5.3950       12
# 994532         1051      0  2016-07-02 06:00:00        12.3025       12
# 994533         1061      0  2016-07-02 06:00:00        27.4850       12
#
#                           primary_use  square_feet  year_built  floor_count  \
# ...

# %%
# df를 site_id, timestamp, building_id를 기준으로 오름차순 정렬하고,
# 인덱스를 초기화하세요.
# Out:
#         building_id  meter            timestamp  meter_reading  site_id  \
# 0                 0      0  2016-01-01 00:00:00          0.000        0
# 1                10      0  2016-01-01 00:00:00          0.000        0
# 2                20      0  2016-01-01 00:00:00          0.000        0
# 3                31      0  2016-01-01 00:00:00          0.000        0
# 4                41      0  2016-01-01 00:00:00          0.000        0
# ...             ...    ...                  ...            ...      ...
# 994529         1417      0  2016-07-02 18:00:00         37.650       15
# 994530         1424      0  2016-07-02 18:00:00         23.375       15
# 994531         1430      2  2016-07-02 18:00:00        150.300       15
# 994532         1436      2  2016-07-02 18:00:00        571.909       15
# 994533         1443      0  2016-07-02 18:00:00         86.925       15
#
#                           primary_use  square_feet  year_built  floor_count  \
# ...

# %%
# df의 정보를 조회하세요.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994534 entries, 0 to 994533
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   building_id         994534 non-null  int64
#  1   meter               994534 non-null  int64
#  2   timestamp           994534 non-null  object
#  3   meter_reading       994534 non-null  float64
#  4   site_id             994534 non-null  int64
#  5   primary_use         994534 non-null  object
#  6   square_feet         994534 non-null  int64
#  7   year_built          387319 non-null  float64
#  8   floor_count         175786 non-null  float64
#  9   air_temperature     994245 non-null  float64
#  10  cloud_coverage      547511 non-null  float64
#  11  dew_temperature     994093 non-null  float64
#  12  precip_depth_1_hr   820289 non-null  float64
#  13  sea_level_pressure  936684 non-null  float64
#  14  wind_direction      930585 non-null  float64
# ...

# %%
# df의 열 별 결측치를 조회하세요.
# Out:
# building_id                0
# meter                      0
# timestamp                  0
# meter_reading              0
# site_id                    0
# primary_use                0
# square_feet                0
# year_built            607215
# floor_count           818748
# air_temperature          289
# cloud_coverage        447023
# dew_temperature          441
# precip_depth_1_hr     174245
# sea_level_pressure     57850
# wind_direction         63949
# wind_speed              2483
# dtype: int64

# %%
# 전체 데이터 중 결측치의 수가 절반을 초과하는 열을 삭제하세요.
# Out:
#         building_id  meter            timestamp  meter_reading  site_id  \
# 0                 0      0  2016-01-01 00:00:00          0.000        0
# 1                10      0  2016-01-01 00:00:00          0.000        0
# 2                20      0  2016-01-01 00:00:00          0.000        0
# 3                31      0  2016-01-01 00:00:00          0.000        0
# 4                41      0  2016-01-01 00:00:00          0.000        0
# ...             ...    ...                  ...            ...      ...
# 994529         1417      0  2016-07-02 18:00:00         37.650       15
# 994530         1424      0  2016-07-02 18:00:00         23.375       15
# 994531         1430      2  2016-07-02 18:00:00        150.300       15
# 994532         1436      2  2016-07-02 18:00:00        571.909       15
# 994533         1443      0  2016-07-02 18:00:00         86.925       15
#
#                           primary_use  square_feet  air_temperature  \
# ...

# %%
# df의 정보를 조회하세요.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994534 entries, 0 to 994533
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   building_id         994534 non-null  int64
#  1   meter               994534 non-null  int64
#  2   timestamp           994534 non-null  object
#  3   meter_reading       994534 non-null  float64
#  4   site_id             994534 non-null  int64
#  5   primary_use         994534 non-null  object
#  6   square_feet         994534 non-null  int64
#  7   air_temperature     994245 non-null  float64
#  8   cloud_coverage      547511 non-null  float64
#  9   dew_temperature     994093 non-null  float64
#  10  precip_depth_1_hr   820289 non-null  float64
#  11  sea_level_pressure  936684 non-null  float64
#  12  wind_direction      930585 non-null  float64
#  13  wind_speed          992051 non-null  float64
# dtypes: float64(8), int64(4), object(2)
# ...

# %%
# df의 열 별 결측치를 조회하세요.
# Out:
# building_id                0
# meter                      0
# timestamp                  0
# meter_reading              0
# site_id                    0
# primary_use                0
# square_feet                0
# air_temperature          289
# cloud_coverage        447023
# dew_temperature          441
# precip_depth_1_hr     174245
# sea_level_pressure     57850
# wind_direction         63949
# wind_speed              2483
# dtype: int64

# %%
# df의 열별 유니크 수를 출력하세요.
# Out:
# building_id             1442
# meter                      4
# timestamp               4412
# meter_reading         293408
# site_id                   16
# primary_use               16
# square_feet             1391
# air_temperature          593
# cloud_coverage            10
# dew_temperature          496
# precip_depth_1_hr         92
# sea_level_pressure       673
# wind_direction            43
# wind_speed                58
# dtype: int64

# %%
# timestamp 열을 datetime64 타입으로 변환한 후 quarter, month, day, hour, dayofweek 정보를 추출하여 새 열에 저장하세요.
# Out:
# C:\Users\Mana\AppData\Local\Temp\ipykernel_46652\1536833801.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp'] = df['timestamp'].astype('datetime64')
# C:\Users\Mana\AppData\Local\Temp\ipykernel_46652\1536833801.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['quarter'] = df['timestamp'].dt.quarter
#    building_id  meter  timestamp  meter_reading  site_id  \
# 0            0      0 2016-01-01            0.0        0
# ...

# %%
# meter 종류별 개수를 출력하세요.
# Out:
# 0    597285
# 1    203995
# 2    130380
# 3     62874
# Name: meter, dtype: int64

# %%
# meter 종류별 meter_reading의 최소, 최대, 평균, 표준편차를 출력하세요.
# Out:
#        min         max          mean            std
# meter
# 0      0.0     21579.0    156.580245     354.693948
# 1      0.0     26067.4    415.905157     983.864646
# 2      0.0  21844500.0  28066.529307  618117.082296
# 3      0.0    105400.0    397.681953    2029.377638

# %%
# site_id별 meter 종류의 개수를 출력하세요.
# Out:
#                 count
# site_id meter
# 0       0       45475
#         1        6809
# 1       0       22416
#         3        5263
# 2       0       59479
#         1       43463
#         3       24020
# 3       0      118931
# 4       0       36340
# 5       0       39009
# 6       0       15854
#         1        7446
#         2        9455
# 7       0        5120
#         1        6368
#         2        5093
#         3        1277
# 8       0       30067
# 9       0       53517
#         1       41972
#         2       38797
# 10      0       12065
#         1        3918
#         3        4898
# 11      0        2134
#         1        1639
#         3        2109
# 12      0       15792
# 13      0       62084
#         1       35340
#         2       38718
# 14      0       44386
#         1       37341
#         2       18703
#         3       24710
# 15      0       34616
#         1       19699
#         2       19614
#         3         597

# %%
# 월 별 meter 0번에 대한 meter_reading의 최소, 최대, 평균, 중앙값을 출력하세요.
# Out:
#        min       max        mean   median
# month
# 1      0.0   6407.33  147.273260  53.9215
# 2      0.0  21579.00  153.933457  55.5000
# 3      0.0   6352.69  148.905411  52.0000
# 4      0.0   6272.68  147.687980  52.5624
# 5      0.0   6260.79  157.267475  55.8000
# 6      0.0   8258.00  183.786981  68.1335
# 7      0.0   6095.00  162.058121  55.0265

# %%
# primary_use 별 square_feet의 최소, 최대, 평균, 중앙값을 출력하세요.
# primary_use를 기준으로 오름차순 정렬하세요.
# 소수점 셋째자리까지 출력하세요.
# Out:
#                                  min     max        mean         std
# primary_use
# Education                       2010  764237  120051.194  104506.933
# Entertainment/public assembly    356  875000  107348.610  139021.156
# Food sales and service         24867   69876   39523.906   16948.423
# Healthcare                      9813  819577  138770.195  140731.494
# Lodging/residential             2000  745671  100978.861  112663.873
# Manufacturing/industrial        3853  111518   42357.960   33463.020
# Office                          2260  861524   97122.239  116875.718
# Other                           1566  226506   28164.718   45517.649
# Parking                         1760  679614  291156.615  195117.578
# Public services                 2818  555243   87671.700  117512.039
# Religious worship               1629   22201   12741.573    8712.602
# Retail                           283  161755   41054.681   41345.153
# ...

# %%
# meter 3번에 대한 월 별 meter_reading과 air_temperature의 최소, 최대, 평균, 중앙값을 출력하세요.
# agg함수에 {상위컬럼명:[집계함수1, 집계함수2, 집계함수3], 상위컬럼명2:[집계함수1, 집계함수2, 집계함수...] }
# Out:
#       meter_reading                                 air_temperature        \
#                 min       max        mean    median             min   max
# month
# 1               0.0  105400.0  684.805102  152.3970           -17.8  23.9
# 2               0.0   74272.2  559.658440  114.2980           -28.7  31.7
# 3               0.0   94881.5  493.254143   67.4063           -22.1  32.8
# 4               0.0   48866.8  309.084768   45.1172           -16.1  35.6
# 5               0.0   34424.2  206.461686   23.4457            -1.1  38.3
# 6               0.0   44692.6  142.183858    8.7921             7.2  47.2
# 7               0.0   39145.2  223.512438   10.0000            10.5  36.1
#
#
#             mean median
# month
# 1       4.779425   5.00
# 2       8.328180   7.20
# 3      12.774730  12.20
# 4      15.220394  15.10
# 5      19.864427  19.75
# 6      26.529446  26.10
# 7      25.338499  25.00

# %%
# meter 3번에 대한 월 별 meter_reading은 최소, 최대, 평균, 표준편차,
# air_temperature는 최소, 최대, 중앙값, IQR을 출력하세요.
# 소수점 셋째자리까지 출력하세요.
# Out:
#       meter_reading                              air_temperature               \
#                 min       max     mean       std             min   max median
# month
# 1               0.0  105400.0  684.805  2527.671           -17.8  23.9   5.00
# 2               0.0   74272.2  559.658  2264.613           -28.7  31.7   7.20
# 3               0.0   94881.5  493.254  3267.983           -22.1  32.8  12.20
# 4               0.0   48866.8  309.085  1213.190           -16.1  35.6  15.10
# 5               0.0   34424.2  206.462   707.596            -1.1  38.3  19.75
# 6               0.0   44692.6  142.184   569.095             7.2  47.2  26.10
# 7               0.0   39145.2  223.512  1731.931            10.5  36.1  25.00
#
#
#           IQR
# month
# 1      12.800
# 2      15.000
# 3      13.300
# 4      13.900
# 5      12.325
# 6      13.400
# 7      10.000

# %%
# 분기, 월, meter, 시간대별 meter_reading의 평균을 출력하세요.
# 결측치는 0으로 치환하세요.
# Out:
# hour                           0             1             2             3   \
# quarter month meter
# 1       1     0        130.618283    123.575139    132.975731    127.096478
#               1        131.841361    136.980174    133.974078    131.132177
#               2       8189.497322  13128.788447   2238.937865   3057.090462
#               3        609.397007    694.882059    932.257701    720.550211
#         2     0        137.257383    134.817179    138.799455    132.306997
#               1        194.794321    177.553240    166.533114    173.872713
#               2      40198.990729   1876.836238   2231.419602   2409.162046
#               3        429.596975    509.450061    495.816290    614.532975
#         3     0        136.266992    127.254953    118.113589    128.917616
#               1        353.036421    313.486144    305.553409    283.551010
#               2      10346.036389  30781.224393  26876.728333  18453.965396
# ...

# %%
# 열 별 결측치를 조회하세요.
# Out:
# building_id                0
# meter                      0
# timestamp                  0
# meter_reading              0
# site_id                    0
# primary_use                0
# square_feet                0
# air_temperature          289
# cloud_coverage        447023
# dew_temperature          441
# precip_depth_1_hr     174245
# sea_level_pressure     57850
# wind_direction         63949
# wind_speed              2483
# quarter                    0
# month                      0
# day                        0
# hour                       0
# dayofweek                  0
# dtype: int64

# %%
# air_temperature를 월 별. 시간대 별 평균으로 대체하세요.
# Out:
# 0         25.0
# 1         25.0
# 2         25.0
# 3         25.0
# 4         25.0
#           ...
# 994529    23.9
# 994530    23.9
# 994531    23.9
# 994532    23.9
# 994533    23.9
# Name: air_temperature, Length: 994534, dtype: float64

# %%
# 열 별 결측치를 조회하세요.
# Out:
# building_id                0
# meter                      0
# timestamp                  0
# meter_reading              0
# site_id                    0
# primary_use                0
# square_feet                0
# air_temperature            0
# cloud_coverage        447023
# dew_temperature          441
# precip_depth_1_hr     174245
# sea_level_pressure     57850
# wind_direction         63949
# wind_speed              2483
# quarter                    0
# month                      0
# day                        0
# hour                       0
# dayofweek                  0
# dtype: int64

# %%
# dew_temperature를 월 별. 시간대 별 median으로 대체하세요.
# Out:
# 0         20.0
# 1         20.0
# 2         20.0
# 3         20.0
# 4         20.0
#           ...
# 994529     8.3
# 994530     8.3
# 994531     8.3
# 994532     8.3
# 994533     8.3
# Name: dew_temperature, Length: 994534, dtype: float64

# %%
# 열 별 결측치를 조회하세요.
# Out:
# building_id                0
# meter                      0
# timestamp                  0
# meter_reading              0
# site_id                    0
# primary_use                0
# square_feet                0
# air_temperature            0
# cloud_coverage        447023
# dew_temperature            0
# precip_depth_1_hr     174245
# sea_level_pressure     57850
# wind_direction         63949
# wind_speed              2483
# quarter                    0
# month                      0
# day                        0
# hour                       0
# dayofweek                  0
# dtype: int64

# %%
# cloud_coverage를 월 별 mode로 대체하세요.
# Out:
# 0         6.0
# 1         6.0
# 2         6.0
# 3         6.0
# 4         6.0
#          ...
# 994529    0.0
# 994530    0.0
# 994531    0.0
# 994532    0.0
# 994533    0.0
# Name: cloud_coverage, Length: 994534, dtype: float64

# %%
# 열 별 결측치를 조회하세요.
# Out:
# building_id                0
# meter                      0
# timestamp                  0
# meter_reading              0
# site_id                    0
# primary_use                0
# square_feet                0
# air_temperature            0
# cloud_coverage             0
# dew_temperature            0
# precip_depth_1_hr     174245
# sea_level_pressure     57850
# wind_direction         63949
# wind_speed              2483
# quarter                    0
# month                      0
# day                        0
# hour                       0
# dayofweek                  0
# dtype: int64

# %%
# 기온을 20개 일정한 간격을 갖는 구간으로 구간화한 후 기온 구간별 sea_level_pressure와 wind_speed의 평균과 표준편차를 출력하세요.
# 구간 값을 기준으로 오름차순 정렬하세요.
# Out:
#                  sea_level_pressure           wind_speed
#                                mean       std       mean       std
# air_temperature
# (-28.876, -25.0]        1027.209119  4.217263   4.843396  1.504673
# (-25.0, -21.2]          1025.310117  4.459950   4.104129  1.668534
# (-21.2, -17.4]          1025.784877  6.982051   3.302589  2.336789
# (-17.4, -13.6]          1023.830490  7.770642   3.842075  2.277812
# (-13.6, -9.8]           1023.403792  7.658642   4.033042  2.583465
# (-9.8, -6.0]            1020.633759  8.190026   4.062750  2.522318
# (-6.0, -2.2]            1019.110774  8.399735   3.900740  2.790833
# (-2.2, 1.6]             1017.427221  8.380977   3.447809  2.325714
# (1.6, 5.4]              1015.961606  9.480738   3.916924  2.540230
# (5.4, 9.2]              1016.076403  9.242027   3.807071  2.605092
# (9.2, 13.0]             1015.714236  7.589944   3.582580  2.499105
# (13.0, 16.8]            1015.587091  6.594170   3.456910  2.296639
# ...

# %%
# 새 열 'energy_production'을 추가합니다.
# meter_reading이 0보다 크면 consumption, 0 이하이면 production 값을 갖도록 설정하세요.
# Out:
#         building_id  meter           timestamp  meter_reading  site_id  \
# 0                 0      0 2016-01-01 00:00:00          0.000        0
# 1                10      0 2016-01-01 00:00:00          0.000        0
# 2                20      0 2016-01-01 00:00:00          0.000        0
# 3                31      0 2016-01-01 00:00:00          0.000        0
# 4                41      0 2016-01-01 00:00:00          0.000        0
# ...             ...    ...                 ...            ...      ...
# 994529         1417      0 2016-07-02 18:00:00         37.650       15
# 994530         1424      0 2016-07-02 18:00:00         23.375       15
# 994531         1430      2 2016-07-02 18:00:00        150.300       15
# 994532         1436      2 2016-07-02 18:00:00        571.909       15
# 994533         1443      0 2016-07-02 18:00:00         86.925       15
#
#                           primary_use  square_feet  air_temperature  \
# ...

# %%
# 각 meter 값에 대한 meter_reading의 tukey fence(IQR의 1.5배 위아래)를 계산하세요.
# Out:
#          tukey_max    tukey_min
# meter
# 0       364.565000  -192.835000
# 1       964.465625  -569.925375
# 2      2871.687500 -1630.292500
# 3       738.844300  -439.498500

# %%
# 새 열 'amount'를 추가합니다.
# 위에서 계산한 각 meter별 tukey_fence를 이용하여 tukey fence 범위 내면 "normal", 범위 밖이면 "high"를 갖도록 설정하세요.
# Out:
#         building_id  meter           timestamp  meter_reading  site_id  \
# 0                 0      0 2016-01-01 00:00:00          0.000        0
# 1                10      0 2016-01-01 00:00:00          0.000        0
# 2                20      0 2016-01-01 00:00:00          0.000        0
# 3                31      0 2016-01-01 00:00:00          0.000        0
# 4                41      0 2016-01-01 00:00:00          0.000        0
# ...             ...    ...                 ...            ...      ...
# 994529         1417      0 2016-07-02 18:00:00         37.650       15
# 994530         1424      0 2016-07-02 18:00:00         23.375       15
# 994531         1430      2 2016-07-02 18:00:00        150.300       15
# 994532         1436      2 2016-07-02 18:00:00        571.909       15
# 994533         1443      0 2016-07-02 18:00:00         86.925       15
#
#                           primary_use  square_feet  air_temperature  \
# ...

# %%
# energy_production과 amount별 meter_reading의 평균, 표준편차, 중앙값을 출력하세요.
# Out:
#                                   mean            std    median
# energy_production amount
# consumption       high    33917.678098  672966.140438  1016.025
#                   normal    172.554835     313.576088    72.240
# production        normal      0.000000       0.000000     0.000
