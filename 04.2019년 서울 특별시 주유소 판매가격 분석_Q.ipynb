# %% [markdown]
# ### WORKSHOP 서울특별시 주유소 판매가격 분석

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 1. 데이터 불러오기

# %%
# 상반기 주유소 판매 데이터 불러오기 encoding="cp949"

first =    
first
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 90585  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190626  GS칼텍스   셀프
# 90586  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190627  GS칼텍스   셀프
# 90587  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190628  GS칼텍스   셀프
# 90588  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190629  GS칼텍스   셀프
# 90589  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20190630  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %%
second =  
second
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190701  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190702  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190703  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190704  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190705  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %%
# first 데이터프레임의 정보를 조회하세요.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90590 entries, 0 to 90589
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   번호      90590 non-null  object
#  1   지역      90590 non-null  object
#  2   상호      90590 non-null  object
#  3   주소      90590 non-null  object
#  4   기간      90590 non-null  int64
#  5   상표      90590 non-null  object
#  6   셀프여부    90590 non-null  object
#  7   고급휘발유   90590 non-null  int64
#  8   휘발유     90590 non-null  int64
#  9   경유      90590 non-null  int64
#  10  실내등유    90590 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 7.6+ MB

# %%
# second 데이터프레임의 정보를 조회하세요.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91124 entries, 0 to 91123
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   번호      91124 non-null  object
#  1   지역      91124 non-null  object
#  2   상호      91124 non-null  object
#  3   주소      91124 non-null  object
#  4   기간      91124 non-null  int64
#  5   상표      91124 non-null  object
#  6   셀프여부    91124 non-null  object
#  7   고급휘발유   91124 non-null  int64
#  8   휘발유     91124 non-null  int64
#  9   경유      91124 non-null  int64
#  10  실내등유    91124 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 7.6+ MB

# %%
# 상반기 판매가격 데이터 프레임 결측치 조회하세요.
# Out:
# 번호       0
# 지역       0
# 상호       0
# 주소       0
# 기간       0
# 상표       0
# 셀프여부     0
# 고급휘발유    0
# 휘발유      0
# 경유       0
# 실내등유     0
# dtype: int64

# %%
# 하반기 판매가격 데이터 프레임 결측치 조회하세요
# Out:
# 번호       0
# 지역       0
# 상호       0
# 주소       0
# 기간       0
# 상표       0
# 셀프여부     0
# 고급휘발유    0
# 휘발유      0
# 경유       0
# 실내등유     0
# dtype: int64

# %% [markdown]
# # 2. 데이터 결합

# %%
# 상반기와 하반기 데이터를 상하로 결합하세요.

df =  
df
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %% [markdown]
# # 3. 데이터 탐색

# %%
# 데이터 프레임 정보 조회하세요.

# code here
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 181714 entries, 0 to 91123
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   번호      181714 non-null  object
#  1   지역      181714 non-null  object
#  2   상호      181714 non-null  object
#  3   주소      181714 non-null  object
#  4   기간      181714 non-null  int64
#  5   상표      181714 non-null  object
#  6   셀프여부    181714 non-null  object
#  7   고급휘발유   181714 non-null  int64
#  8   휘발유     181714 non-null  int64
#  9   경유      181714 non-null  int64
#  10  실내등유    181714 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 16.6+ MB

# %%
# '상표' 컬럼의 고유값 조회하세요.

# code here
# Out:
# array(['SK에너지', 'GS칼텍스', 'S-OIL', '현대오일뱅크', '알뜰주유소', 'NH-OIL', '알뜰(ex)',
#        '자가상표'], dtype=object)

# %%
# '상표'컬럼의 항목별 빈도를 조회하세요.

# code here
# Out:
# 상표
# SK에너지     71062
# GS칼텍스     49494
# 현대오일뱅크    28583
# S-OIL     27027
# 알뜰주유소      4021
# 자가상표        982
# 알뜰(ex)      365
# NH-OIL      180
# Name: count, dtype: int64

# %%
# '지역' 컬럼의 고유값 조회하세요.

# code here
# Out:
# array(['서울 강남구', '서울 강동구', '서울 강북구', '서울 강서구', '서울 관악구', '서울 광진구',
#        '서울 구로구', '서울 금천구', '서울 노원구', '서울 도봉구', '서울 동대문구', '서울 동작구',
#        '서울 마포구', '서울 서대문구', '서울 서초구', '서울 성동구', '서울 성북구', '서울 송파구',
#        '서울 양천구', '서울 영등포구', '서울 용산구', '서울 은평구', '서울 종로구', '서울 중구',
#        '서울 중랑구'], dtype=object)

# %%
# '지역'컬럼의 항목별 빈도를 조회하세요.

# code here
# Out:
# 지역
# 서울 강남구     14597
# 서울 서초구     13762
# 서울 강서구     12572
# 서울 영등포구    11667
# 서울 송파구     11630
# 서울 양천구      9149
# 서울 성북구      8080
# 서울 동대문구     7996
# 서울 구로구      7917
# 서울 도봉구      6711
# 서울 광진구      6450
# 서울 은평구      6199
# 서울 성동구      6192
# 서울 관악구      5997
# 서울 강동구      5897
# 서울 중랑구      5719
# 서울 서대문구     5594
# 서울 노원구      5466
# 서울 용산구      5439
# 서울 금천구      4738
# 서울 강북구      4736
# 서울 중구       4235
# 서울 마포구      4051
# 서울 동작구      3644
# 서울 종로구      3276
# Name: count, dtype: int64

# %%
# 상호별 데이터 건수를 출력하세요.
# code here
# Out:
# 상호
# 신성주유소            1095
# 대성주유소             730
# 동일주유소             730
# 현대주유소             591
# (주)동하힐탑셀프주유소      365
#                  ...
# 관악로주유소             63
# 엘스카운티(주)천동주유소      62
# 위례제일주유소            39
# (주)승지 염리동주유소       34
# 삼성주유소              27
# Name: count, Length: 507, dtype: int64

# %%
# 셀프여부 컬럼에 대한 데이터 건수를 출력하세요
# code here
# Out:
# 셀프여부
# 일반    108492
# 셀프     73222
# Name: count, dtype: int64

# %%
# 고급휘발유,휘발유,경유,실내등유 4개의 컬럼에 대해 상자그림(박스플랏)을 그려보세요. 
# code here
# Out:
# <Axes: >

# %%
# 위에서 그린 고급휘발유,휘발유,경유,실내등유 4개의 컬럼에 대해 상자그림(박스플랏)을 
# 변형하여 각각의 박스플랏을 그려보세요.  

# code here

# %%
#고급휘발유,휘발유,경유,실내등유 4개의 컬럼에 대해 통계적 요약정보를 출력하세요.
# code here
# Out:
#                고급휘발유            휘발유             경유           실내등유
# count  181714.000000  181714.000000  181714.000000  181714.000000
# mean      763.284139    1567.148161    1435.564816     454.800412
# std       937.368150     182.942737     171.892815     572.002790
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000    1459.000000    1333.000000       0.000000
# 50%         0.000000    1529.000000    1389.000000       0.000000
# 75%      1768.000000    1599.000000    1478.000000    1100.000000
# max      2699.000000    2356.000000    2196.000000    1640.000000

# %%
# 고급휘발유 컬럼의 0의 비율을 출력하세요. df의 전체 데이터 건수 대비  
# code here
# Out:
# 0.5957493643857931

# %%
#휘발유 컬럼의 0의 비율을 출력하세요. df의 전체 데이터 건수 대비  
# code here
# Out:
# 0.00024213874550117217

# %%
#경유 컬럼의 0의 비율을 출력하세요. df의 전체 데이터 건수 대비  
# code here
# Out:
# 0.00024213874550117217

# %%
#실내등유 컬럼의 0의 비율을 출력하세요. df의 전체 데이터 건수 대비  
# code here
# Out:
# 0.6084286296047635

# %%
# 고급휘발유에 대해 히스토그램과 kde 그래프를 겹쳐 그리세요. 
# code here
# Out:
# <Axes: ylabel='Density'>

# %%
# 휘발유에 대해 히스토그램과 kde 그래프를 겹쳐 그리세요. 

# code here
# Out:
# <Axes: ylabel='Density'>

# %%
# 경유에 대해 히스토그램과 kde 그래프를 겹쳐 그리세요. 

# code here
# Out:
# <Axes: ylabel='Density'>

# %%
# 실내등유에 대해 히스토그램과 kde 그래프를 겹쳐 그리세요. 

# code here
# Out:
# <Axes: ylabel='Density'>

# %%
# 함수 작성 후 실행해보세요. 
# 함수명은 feature_explore, 인자는 데이터프레임 
# 기능: 인자로 받은 데이터프레임에 대해서 각 컬럼에 대한 데이터타입이 object 타입이면 빈도분석(데이터별 건수), 
#       int 나 float 이면 통계적 요약정보 출력  


# code here
# Out:
# 컬럼명: 번호, 자료형: object
# 번호
# A0006039    365
# A0009861    365
# A0009515    365
# A0009500    365
# A0009507    365
#            ...
# A0001156     63
# A0009825     62
# A0033424     39
# A0000182     34
# A0001220     27
# Name: count, Length: 512, dtype: int64
# ------------------------------
# 컬럼명: 지역, 자료형: object
# 지역
# 서울 강남구     14597
# 서울 서초구     13762
# 서울 강서구     12572
# 서울 영등포구    11667
# 서울 송파구     11630
# 서울 양천구      9149
# 서울 성북구      8080
# 서울 동대문구     7996
# 서울 구로구      7917
# 서울 도봉구      6711
# 서울 광진구      6450
# 서울 은평구      6199
# 서울 성동구      6192
# 서울 관악구      5997
# 서울 강동구      5897
# 서울 중랑구      5719
# 서울 서대문구     5594
# 서울 노원구      5466
# 서울 용산구      5439
# 서울 금천구      4738
# 서울 강북구      4736
# 서울 중구       4235
# 서울 마포구      4051
# 서울 동작구      3644
# 서울 종로구      3276
# Name: count, dtype: int64
# ------------------------------
# 컬럼명: 상호, 자료형: object
# 상호
# 신성주유소            1095
# 대성주유소             730
# 동일주유소             730
# 현대주유소             591
# ...

# %%
# '지역' 컬럼의 값을 이용하여 '시'와 '구'를 분리하세요. (새컬럼 생성)
# code here
# Out:
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유   시    구
# 0   1673  1465  1365     0  서울  강남구
# 1   1673  1465  1365     0  서울  강남구
# 2   1673  1465  1365     0  서울  강남구
# 3   1673  1465  1365     0  서울  강남구
# 4   1673  1465  1365     0  서울  강남구

# %%
# '시' 컬럼의 서울을 서울특별시로 변환하세요.
# code here
# Out:
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구
# 0   1673  1465  1365     0  서울특별시  강남구
# 1   1673  1465  1365     0  서울특별시  강남구
# 2   1673  1465  1365     0  서울특별시  강남구
# 3   1673  1465  1365     0  서울특별시  강남구
# 4   1673  1465  1365     0  서울특별시  강남구

# %%
# '기간' 컬럼을 datetime 형식으로 변경하세요.
# code here
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구
# 0   1673  1465  1365     0  서울특별시  강남구
# 1   1673  1465  1365     0  서울특별시  강남구
# 2   1673  1465  1365     0  서울특별시  강남구
# 3   1673  1465  1365     0  서울특별시  강남구
# 4   1673  1465  1365     0  서울특별시  강남구

# %%
# 기간 컬럼에서 dt 타입을 이용하여 년, 월, 일, 요일 컬럼 생성 (새컬럼 생성)
# code here
# Out:
#          번호      지역            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유      시    구     년  월  일         요일
# 0   1673  1465  1365     0  서울특별시  강남구  2019  1  1    Tuesday
# 1   1673  1465  1365     0  서울특별시  강남구  2019  1  2  Wednesday
# 2   1673  1465  1365     0  서울특별시  강남구  2019  1  3   Thursday
# 3   1673  1465  1365     0  서울특별시  강남구  2019  1  4     Friday
# 4   1673  1465  1365     0  서울특별시  강남구  2019  1  5   Saturday

# %%
# 휘발유 가격이 비싼 5개 판매가격을 출력하세요.
# code here
# Out:
#              번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 86620  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-24  SK에너지   일반   2649
# 86626  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-30  SK에너지   일반   2699
# 86627  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-10-01  SK에너지   일반   2699
# 86621  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-25  SK에너지   일반   2649
# 86622  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-09-26  SK에너지   일반   2699
#
#         휘발유    경유  실내등유      시   구     년   월   일         요일
# 86620  2356  2196     0  서울특별시  중구  2019   9  24    Tuesday
# 86626  2356  2196     0  서울특별시  중구  2019   9  30     Monday
# 86627  2356  2196     0  서울특별시  중구  2019  10   1    Tuesday
# 86621  2356  2196     0  서울특별시  중구  2019   9  25  Wednesday
# 86622  2356  2196     0  서울특별시  중구  2019   9  26   Thursday

# %%
# 휘발유 가격이 저렴한 5개 판매가격을 출력하세요. (단 휘발유가 0원인 데이터는 제외)
# code here
# Out:
#              번호      지역                   상호                    주소         기간  \
# 13148  A0033328  서울 강서구  KH에너지(주)직영 KH외발산주유소        서울 강서구 방화대로 30 2019-02-07
# 82475  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-31
# 82474  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-01-30
# 82476  A0000605  서울 은평구                삼융주유소  서울 은평구 수색로 299 (수색동) 2019-02-01
# 82998  A0000690  서울 은평구    지에스칼텍스(주)수색뉴타운주유소  서울 은평구 수색로 350 (수색동) 2019-01-26
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유      시    구     년  월   일         요일
# 13148  SK에너지   셀프   1788  1255  1155     0  서울특별시  강서구  2019  2   7   Thursday
# 82475  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  2019  1  31   Thursday
# 82474  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  2019  1  30  Wednesday
# 82476  SK에너지   일반      0  1260  1160     0  서울특별시  은평구  2019  2   1     Friday
# 82998  GS칼텍스   셀프      0  1265  1165     0  서울특별시  은평구  2019  1  26   Saturday

# %%
# 상표별 평균 휘발유 가격을 계산하세요.
# code here
# Out:
#                mean
# 상표
# GS칼텍스   1564.029014
# NH-OIL  1449.088889
# S-OIL   1532.302882
# SK에너지   1612.147153
# 알뜰(ex)  1431.347945
# 알뜰주유소   1447.875902
# 자가상표    1492.085540
# 현대오일뱅크  1515.458244

# %%
# 상표별 평균 휘발유 가격을 시각화하세요.
# code here
# Out:
# <Axes: xlabel='상표'>

# %%
# 상표와 셀프여부별 평균 휘발유 가격을 계산하세요.
# code here
# Out:
#                     mean
# 상표     셀프여부
# GS칼텍스  셀프    1481.410074
#        일반    1610.060123
# NH-OIL 일반    1449.088889
# S-OIL  셀프    1481.437428
#        일반    1579.451162
# SK에너지  셀프    1504.853863
#        일반    1690.377765
# 알뜰(ex) 셀프    1431.347945
# 알뜰주유소  셀프    1434.726027
#        일반    1455.372511
# 자가상표   셀프    1494.409449
#        일반    1491.740351
# 현대오일뱅크 셀프    1483.546767
#        일반    1534.254225

# %%
# 상표와 셀프여부별 평균 휘발유 가격을 시각화하세요.
# code here
# Out:
# <Axes: xlabel='상표,셀프여부'>

# %%
# 상표와 셀프여부를 데이터개수로 표현하세요.
brand_pv = # code here 
brand_pv
# Out:
# 셀프여부       셀프      일반     All
# 상표
# GS칼텍스   17709   31785   49494
# NH-OIL      0     180     180
# S-OIL   13001   14026   27027
# SK에너지   29965   41097   71062
# 알뜰(ex)    365       0     365
# 알뜰주유소    1460    2561    4021
# 자가상표      127     855     982
# 현대오일뱅크  10595   17988   28583
# All     73222  108492  181714

# %%
# 위의 결과를 보고 아래 질문에 답하세요. 
# 서울지역의 주유소에서 가장 점유율이 높은 브랜드(상표)는?   
# 셀프서비스를 하지 않는 브랜드는?  
# 일반 서비스를 하지 않는 브랜드는?

# %%
# 위의 brand_pv 데이터프레임에서 셀프 주유소의 비율은? 
# 소수점 둘쨰자리에서 반올림 
#73222/181714

# code here
# Out:
# '셀프 주유소의 비율 : 40.30%'

# %%
# 위의 brand_pv 데이터프레임에서 일반 주유소의 비율은? 
# 소수점 둘쨰자리에서 반올림 
# 108492/181714

# code here
# Out:
# '일반 주유소의 비율: 59.70%'

# %%
# 셀프여부에 따라 휘발유 가격을 boxplot으로 시각화해보세요.
# 휘발유가 0인 데이터는 제외하고 시각화합니다.

# code here

# %%
# 휘발유 가격과 일반 주유소의 가격을 boxplot을 이용하여 시각화해보세요.
# 휘발유가 0인 데이터는 제외하고 시각화합니다.

# code here

# %% [markdown]
# ### 지역 및 상호분석

# %%
# 지역별 평균 휘발유 가격을 계산하세요
# code here
# Out:
#              mean
# 구
# 중구    1976.948052
# 용산구   1882.049825
# 종로구   1838.554945
# 강남구   1713.093581
# 마포구   1689.755616
# 성동구   1583.659561
# 서초구   1577.131304
# 강동구   1576.685264
# 영등포구  1568.279506
# 노원구   1531.221551
# 서대문구  1528.943332
# 구로구   1525.410383
# 송파구   1518.957954
# 관악구   1518.128564
# 양천구   1512.890261
# 동작구   1512.470911
# 성북구   1507.948267
# 동대문구  1506.833542
# 도봉구   1494.171062
# 광진구   1490.597054
# 강서구   1488.818088
# 은평구   1481.964026
# 금천구   1477.121992
# 중랑구   1469.009092
# 강북구   1453.517525

# %%
# 지역별 평균 휘발유 가격을 시각화하세요.
# code here
# Out:
# <Axes: xlabel='구'>

# %%
# 월별 구별 평균 휘발유 가격을 구하세요.
# 평균 휘발유 가격으로 저렴한 순으로 10개를 출력하세요. (오름차순)
# code here
# Out:
#                휘발유
# 월 구
# 2 은평구  1330.018908
#   금천구  1337.986264
# 3 강북구  1342.990074
# 2 중랑구  1343.332589
#   강북구  1345.565934
# 1 강북구  1357.002488
#   금천구  1360.297767
#   중랑구  1360.405242
# 2 광진구  1362.851190
# 1 은평구  1363.895636

# %%
# 월별 구별 상호별 평균 휘발유 가격을 구하세요.
# 평균 휘발유 가격으로 저렴한 순으로 10개를 출력하세요. (오름차순)
# code here
# Out:
#                                     휘발유
# 월 구    상호
# 3 강동구  엘스카운티(주)천동주유소           0.000000
#   관악구  관악로주유소                744.500000
# 5 동대문구 배봉로주유소                847.500000
# 2 용산구  강변주유소                 952.607143
# 1 동대문구 SK경동주유소              1247.935484
#   강서구  강서오곡셀프주유소            1276.677419
# 2 강서구  강서오곡셀프주유소            1282.357143
#        KH에너지(주)직영 KH외발산주유소  1282.857143
#   은평구  지에스칼텍스(주)수색뉴타운주유소    1284.714286
#        타이거주유소               1287.142857

# %%
# 3월달 '엘스카운티(주)천동주유소' 의 데이터를 출력하세요.
# 3월 가격이 입력되어 있지 않습니다. 
# code here
# Out:
#             번호      지역             상호                     주소         기간  \
# 9495  A0009825  서울 강동구  엘스카운티(주)천동주유소  서울 강동구 천호대로 987 (천호동) 2019-03-01
# 9496  A0009825  서울 강동구  엘스카운티(주)천동주유소  서울 강동구 천호대로 987 (천호동) 2019-03-02
# 9497  A0009825  서울 강동구  엘스카운티(주)천동주유소  서울 강동구 천호대로 987 (천호동) 2019-03-03
#
#           상표 셀프여부  고급휘발유  휘발유  경유  실내등유      시    구     년  월  일        요일
# 9495  현대오일뱅크   일반      0    0   0  1190  서울특별시  강동구  2019  3  1    Friday
# 9496  현대오일뱅크   일반      0    0   0  1190  서울특별시  강동구  2019  3  2  Saturday
# 9497  현대오일뱅크   일반      0    0   0  1190  서울특별시  강동구  2019  3  3    Sunday

# %%
# 휘발유가격이 0으로 표기된 자료는 제외하고
# 위에서 구한 월별 구별 상호별 휘발유가격의 평균을 구하세요. 
# 휘발유 평균가격으로 저렴한 순으로 10개를 출력하세요. (오름차순)
# code here
# Out:
#                                    휘발유
# 월 구   상호
# 1 강서구 강서오곡셀프주유소            1276.677419
# 2 강서구 강서오곡셀프주유소            1282.357143
#       KH에너지(주)직영 KH외발산주유소  1282.857143
#   은평구 지에스칼텍스(주)수색뉴타운주유소    1284.714286
#       타이거주유소               1287.142857
#       (주)명연에너지 수색훼미리주유소    1287.857143
#       삼융주유소                1288.678571
# 1 은평구 (주)명연에너지 수색훼미리주유소    1292.000000
#       타이거주유소               1293.419355
#       지에스칼텍스(주)수색뉴타운주유소    1294.354839

# %%
# 휘발유가격이 0으로 표기된 자료는 제외하고
# 위에서 구한 월별 구별 상호별 휘발유가격 평균, 표준편차를 구하세요. 


# code here
# Out:
#                                       휘발유
#                                      mean        std
# 월  구   상호
# 1  강남구 (주)동하힐탑셀프주유소           1450.806452   9.228288
#        (주)만정에너지               1918.354839  20.320020
#        (주)보성 세곡주유소            1382.000000  21.166010
#        (주)선진도곡주유소             1465.322581  18.526354
#        (주)소모에너지엔테크놀러지 쎈트럴주유소  1697.483871  24.128643
# ...                                   ...        ...
# 12 중랑구 우림주유소                  1529.354839   8.240341
#        재원에너지㈜ 범아주유소           1543.806452   9.228288
#        중랑교                    1579.967742   7.002304
#        지에스칼텍스㈜ 대원주유소          1515.806452   7.569321
#        지에스칼텍스㈜ 소망주유소          1540.000000   0.000000
#
# [6007 rows x 2 columns]

# %%
# mgn_df 컬럼의 멀티인덱스를  싱글인덱스로 변경하세요. 

# code here
# Out:
# Index(['mean', 'std'], dtype='object')

# %%
# mgn_df 에 cv 컬럼을 추가하여 변동계수를 출력하세요. 
# cv기준으로 오름차순으로 출력하세요. 
# code here
# Out:
#                               mean         std        cv
# 월  구    상호
# 12 중랑구  지에스칼텍스㈜ 소망주유소  1540.000000    0.000000  0.000000
# 10 구로구  SK구로주유소        1588.000000    0.000000  0.000000
#         구로주유소          2064.000000    0.000000  0.000000
#         동아주유소          1768.000000    0.000000  0.000000
#         시몬주유소          1547.000000    0.000000  0.000000
# ...                            ...         ...       ...
# 11 도봉구  해와달주유소         1716.466667  169.895654  0.098980
# 4  도봉구  해와달주유소         1810.620690  187.459027  0.103533
# 2  영등포구 sk여명주유소        1508.285714  216.843493  0.143768
# 5  동대문구 배봉로주유소         1695.000000         NaN       NaN
#    서대문구 (주)창원현대주유소     1449.000000         NaN       NaN
#
# [6007 rows x 3 columns]

# %% [markdown]
# #####  각 월마다 착한 주유소 찿기

# %%
# mgn_df 를 cv가 0 이 아닌 데이터에 대해서 cv에 대한 오름차순 정렬후 상위 10개를 출력하세요. 
# code here
# Out:
#                                     mean       std        cv
# 월  구    상호
# 7  송파구  서원주유소                1599.032258  0.179605  0.000112
# 4  중구   SC(주) 역전주유소          1998.900000  0.305129  0.000153
# 9  영등포구 (주)한미석유 제2한강주유소      1566.066667  0.365148  0.000233
# 11 서초구  강남대로주유소              1549.200000  0.406838  0.000263
# 7  강북구  현대오일뱅크(주)직영 번동셀프주유소  1466.709677  0.461414  0.000315
# 11 강서구  지에스칼텍스㈜ 경인고속주유소      1498.333333  0.479463  0.000320
# 12 영등포구 선유도주유소               1566.096774  0.538816  0.000344
# 9  강남구  금성주유소                1998.866667  0.730297  0.000365
# 1  영등포구 남부(영등포)              1399.096774  0.538816  0.000385
# 6  서초구  전당앞주유소               1598.857143  0.755929  0.000473

# %% [markdown]
# ##### 휘발유를 전체 평균보다 항상 저렴하게 판매한 착한 주유소 찾기

# %%
# 월별, 일별로 휘발유가격의 평균가격을 구하세요. 
mdm_df =  # code here 
mdm_df
# Out:
#                휘발유
# 월  일
# 1  1   1493.439842
#    2   1489.710059
#    3   1485.027613
#    4   1482.749012
#    5   1477.875248
# ...            ...
# 12 27  1635.878296
#    28  1636.488844
#    29  1636.676829
#    30  1634.056795
#    31  1638.573171
#
# [365 rows x 1 columns]

# %%
# 상호별, 월별, 일별 휘발유 가격의 평균구하여, 앞에서 20개만 출력해보세요.
# code here
# Out:
#                             휘발유
# 상호                 월 일
#  현대오일뱅크㈜직영 구로셀프주유소 1 1   1387.0
#                      2   1349.0
#                      3   1349.0
#                      4   1349.0
#                      5   1349.0
#                      6   1349.0
#                      7   1349.0
#                      8   1349.0
#                      9   1349.0
#                      10  1349.0
#                      11  1349.0
#                      12  1344.0
#                      13  1344.0
#                      14  1344.0
#                      15  1344.0
#                      16  1344.0
#                      17  1329.0
#                      18  1329.0
#                      19  1329.0
#                      20  1329.0

# %%
# df에서 상호, 월, 일, 휘발유 열만 추려서 새로 데이터 프레임을 만들고, 
# 만든 데이터 프레임의 인덱스를 [월,일] 로 설정하세요.  
 
sangho_df = # code here 
sangho_df
# Out:
#                   상호   휘발유
# 월  일
# 1  1    (주)동하힐탑셀프주유소  1465
#    2    (주)동하힐탑셀프주유소  1465
#    3    (주)동하힐탑셀프주유소  1465
#    4    (주)동하힐탑셀프주유소  1465
#    5    (주)동하힐탑셀프주유소  1465
# ...              ...   ...
# 12 27  지에스칼텍스㈜ 소망주유소  1540
#    28  지에스칼텍스㈜ 소망주유소  1540
#    29  지에스칼텍스㈜ 소망주유소  1540
#    30  지에스칼텍스㈜ 소망주유소  1540
#    31  지에스칼텍스㈜ 소망주유소  1540
#
# [181714 rows x 2 columns]

# %%
# 아래와 같이 인덱스를 변경하세요. 
# code here
# Out:
#                           상호   휘발유
# 월  일
# 1  1            (주)동하힐탑셀프주유소  1465
#    1                (주)만정에너지  1939
#    1             (주)보성 세곡주유소  1438
#    1              (주)선진도곡주유소  1495
#    1   (주)소모에너지엔테크놀러지 쎈트럴주유소  1699
# ...                      ...   ...
# 12 31                  우림주유소  1535
#    31           재원에너지㈜ 범아주유소  1558
#    31                    중랑교  1589
#    31          지에스칼텍스㈜ 대원주유소  1523
#    31          지에스칼텍스㈜ 소망주유소  1540
#
# [181714 rows x 2 columns]

# %%
# 위에서 만든 sangho_df 에서 인덱스가 1월1일인 데이터에 대해서,  mdm_df의 1월1일 데이터와의 차이를 구해 새로운 컬럼 diff 를 생성하세요. 
# 멀티인덱스 사용 
# code here
# Out:
#                           상호   휘발유        diff
# 월  일
# 1  1            (주)동하힐탑셀프주유소  1465  -28.439842
#    1                (주)만정에너지  1939  445.560158
#    1             (주)보성 세곡주유소  1438  -55.439842
#    1              (주)선진도곡주유소  1495    1.560158
#    1   (주)소모에너지엔테크놀러지 쎈트럴주유소  1699  205.560158
# ...                      ...   ...         ...
# 12 31                  우림주유소  1535         NaN
#    31           재원에너지㈜ 범아주유소  1558         NaN
#    31                    중랑교  1589         NaN
#    31          지에스칼텍스㈜ 대원주유소  1523         NaN
#    31          지에스칼텍스㈜ 소망주유소  1540         NaN
#
# [181714 rows x 3 columns]

# %%
# 위에서 만든 sangho_df에 대해서 1월1일에 대한 데이터를 조회하세요. 
# code here
# Out:
#                         상호   휘발유        diff
# 월 일
# 1 1           (주)동하힐탑셀프주유소  1465  -28.439842
#   1               (주)만정에너지  1939  445.560158
#   1            (주)보성 세곡주유소  1438  -55.439842
#   1             (주)선진도곡주유소  1495    1.560158
#   1  (주)소모에너지엔테크놀러지 쎈트럴주유소  1699  205.560158
# ..                     ...   ...         ...
#   1                  우림주유소  1375 -118.439842
#   1           재원에너지㈜ 범아주유소  1379 -114.439842
#   1                    중랑교  1389 -104.439842
#   1          지에스칼텍스㈜ 대원주유소  1377 -116.439842
#   1          지에스칼텍스㈜ 소망주유소  1428  -65.439842
#
# [507 rows x 3 columns]

# %%
# 모든 월, 일에 대해 위의 셀과 마찬가지로 for 문을 돌면서 
# sangho_df의 휘발유가격 - mdm_df의 휘발유 가격의 차이를 구해 sangho_df의 diff 컬럼에 저장하세요. 

# code here
# Out:
#                           상호   휘발유        diff
# 월  일
# 1  1            (주)동하힐탑셀프주유소  1465  -28.439842
#    1                (주)만정에너지  1939  445.560158
#    1             (주)보성 세곡주유소  1438  -55.439842
#    1              (주)선진도곡주유소  1495    1.560158
#    1   (주)소모에너지엔테크놀러지 쎈트럴주유소  1699  205.560158
# ...                      ...   ...         ...
# 12 31                  우림주유소  1535 -103.573171
#    31           재원에너지㈜ 범아주유소  1558  -80.573171
#    31                    중랑교  1589  -49.573171
#    31          지에스칼텍스㈜ 대원주유소  1523 -115.573171
#    31          지에스칼텍스㈜ 소망주유소  1540  -98.573171
#
# [181714 rows x 3 columns]

# %%
# sangho_df 의 8월8일의 정보를 출력하세요. 
sangho_df.loc[(8,8)]
# Out:
#                         상호   휘발유        diff
# 월 일
# 8 8           (주)동하힐탑셀프주유소  1595    6.771084
#   8               (주)만정에너지  1999  410.771084
#   8            (주)보성 세곡주유소  1507  -81.228916
#   8             (주)선진도곡주유소  1597    8.771084
#   8  (주)소모에너지엔테크놀러지 쎈트럴주유소  1988  399.771084
# ..                     ...   ...         ...
#   8                  우림주유소  1469 -119.228916
#   8           재원에너지㈜ 범아주유소  1498  -90.228916
#   8                    중랑교  1539  -49.228916
#   8          지에스칼텍스㈜ 대원주유소  1487 -101.228916
#   8          지에스칼텍스㈜ 소망주유소  1548  -40.228916
#
# [498 rows x 3 columns]

# %%
# 휘발유 가격이 0인 데이터가 존재하므로  sangho_df의 휘발유열에 값이 0이 아닌 데이터만 가져오세요. 
# diff 가격을 오름차순으로 정렬하여 top20 개를 출력하세요. 
# code here
# Out:
#             상호   휘발유        diff
# 월 일
# 5 29  (주)석산에너지  1412 -213.917505
#   28  (주)석산에너지  1412 -213.601610
#   27  (주)석산에너지  1412 -213.289738
# 6 1   (주)석산에너지  1412 -213.206061
# 5 26  (주)석산에너지  1412 -213.121457
# 6 2   (주)석산에너지  1412 -212.724138
# 5 24  (주)석산에너지  1412 -212.419679
#   25  (주)석산에너지  1412 -212.342052
#   23  (주)석산에너지  1412 -211.698189
#   30  (주)석산에너지  1412 -211.106640
#   22  (주)석산에너지  1412 -210.626506
#   31  (주)석산에너지  1412 -210.565392
# 6 5   (주)석산에너지  1412 -210.102410
#   3   (주)석산에너지  1412 -209.672032
# 5 21  (주)석산에너지  1412 -209.301205
# 6 6   (주)석산에너지  1412 -208.748996
#   4   (주)석산에너지  1412 -208.351406
#   7   (주)석산에너지  1412 -206.981928
# 5 20  (주)석산에너지  1412 -206.345382
#   19  (주)석산에너지  1412 -206.036290

# %%
# 위의 결과에 (주)석산에너지를 df에서 찾아보세요.
# code here
# Out:
#              번호      지역        상호                    주소         기간      상표  \
# 10221  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-01-01   S-OIL
# 10222  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-01-02   S-OIL
# 10223  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-01-03   S-OIL
# 10224  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-01-04   S-OIL
# 10225  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-01-05   S-OIL
# ...         ...     ...       ...                   ...        ...     ...
# 10452  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-12-27  현대오일뱅크
# 10453  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-12-28  현대오일뱅크
# 10454  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-12-29  현대오일뱅크
# 10455  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-12-30  현대오일뱅크
# 10456  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-12-31  현대오일뱅크
#
# ...

# %%
# df에서 5월 6월달에 석산에너지의 정보를 출력하세요.
# code here
# Out:
#              번호      지역        상호                    주소         기간      상표  \
# 10341  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-05-01   S-OIL
# 10342  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-05-02   S-OIL
# 10343  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-05-08  현대오일뱅크
# 10344  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-05-09  현대오일뱅크
# 10345  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-05-10  현대오일뱅크
# 10346  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-05-11  현대오일뱅크
# 10347  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-05-12  현대오일뱅크
# 10348  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-05-13  현대오일뱅크
# 10349  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-05-14  현대오일뱅크
# 10350  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-05-15  현대오일뱅크
# 10351  A0009641  서울 강북구  (주)석산에너지  서울 강북구 삼양로 316 (수유동) 2019-05-16  현대오일뱅크
# ...

# %%
# 휘발유 가격이 0인 데이터가 존재하므로  sangho_df의 휘발유열에 값이 0이 아닌 데이터만 가져오세요. 
# diff 가격을 오름차순으로 정렬하여 top20개를 출력하세요. 
# code here
# Out:
#           상호   휘발유        diff
# 월  일
# 9  24  서남주유소  2356  712.691532
#    25  서남주유소  2356  712.048387
#    27  서남주유소  2356  711.817269
#    26  서남주유소  2356  711.686117
#    28  서남주유소  2356  711.526104
# 10 1   서남주유소  2356  711.348697
# 9  29  서남주유소  2356  711.290323
#    30  서남주유소  2356  711.108434
# 12 3   서남주유소  2332  707.052525
#    4   서남주유소  2332  706.539394
#    5   서남주유소  2332  706.084848
#    6   서남주유소  2332  705.745455
#    7   서남주유소  2332  705.092929
# 11 19  서남주유소  2325  704.979675
# 12 8   서남주유소  2332  704.711968
# 11 20  서남주유소  2325  704.335366
# 12 9   서남주유소  2332  704.216599
#    10  서남주유소  2332  703.963636
# 11 21  서남주유소  2325  703.819473
#    22  서남주유소  2325  703.123732

# %%
# 위의 결과에서 20번째부터 40번째까지의 행을 출력하세요. 

# code here
# Out:
#           상호   휘발유        diff
# 월  일
# 11 23  서남주유소  2325  702.672065
#    25  서남주유소  2325  702.143725
#    24  서남주유소  2325  702.130081
#    26  서남주유소  2325  701.825911
#    27  서남주유소  2321  698.004040
#    28  서남주유소  2321  697.759596
#    29  서남주유소  2321  697.746450
#    30  서남주유소  2321  697.298990
# 12 2   서남주유소  2321  696.925253
#    1   서남주유소  2321  696.898990
#    24  서남주유소  2327  695.437247
#    17  서남주유소  2327  695.350202
#    18  서남주유소  2327  695.058704
#    19  서남주유소  2327  694.506073
#    20  서남주유소  2327  694.198381
#    11  서남주유소  2323  694.044444
#    13  서남주유소  2323  693.748988
#    21  서남주유소  2327  693.697769
#    22  서남주유소  2327  693.367140
#    12  서남주유소  2323  693.107071

# %%
# 위의 결과에 서남주유소를 df에서 찾아보세요.
# code here
# Out:
#              번호     지역     상호            주소         기간     상표 셀프여부  고급휘발유  \
# 86231  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-01-01  SK에너지   일반   2299
# 86232  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-01-02  SK에너지   일반   2270
# 86233  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-01-03  SK에너지   일반   2270
# 86234  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-01-04  SK에너지   일반   2270
# 86235  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-01-05  SK에너지   일반   2270
# ...         ...    ...    ...           ...        ...    ...  ...    ...
# 86714  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-12-27  SK에너지   일반   2658
# 86715  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-12-28  SK에너지   일반   2658
# 86716  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-12-29  SK에너지   일반   2658
# 86717  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-12-30  SK에너지   일반   2658
# 86718  A0000767  서울 중구  서남주유소  서울 중구 통일로 30 2019-12-31  SK에너지   일반   2674
#
#         휘발유    경유  실내등유      시   구     년   월   일         요일
# ...

# %% [markdown]
# ### 날짜정보 분석

# %%
# 월별 평균 휘발유 가격을 계산하세요. 월별평균가격
# code here
# Out:
#            mean
# 월
# 1   1466.554672
# 2   1446.624956
# 3   1465.159889
# 4   1519.481056
# 5   1606.096255
# 6   1605.343367
# 7   1585.726529
# 8   1589.339464
# 9   1633.125891
# 10  1634.464547
# 11  1620.687606
# 12  1630.535819

# %%
# 월별 평균 휘발유 가격을 막대 그래프와 라인그래프로 시각화 하세요.

# code here
# Out:
# <Axes: xlabel='월'>

# %%
# pivot_table 함수를 이용하여 구와 월 컬럼을 이용하여 평균 휘발유 가격을 계산하세요
# code here
# Out:
# 구           강남구          강동구          강북구          강서구          관악구  \
# 월
# 1   1619.865825  1503.383302  1357.002488  1376.357474  1429.822262
# 2   1600.945536  1478.109244  1345.565934  1370.397959  1405.984127
# 3   1616.143548  1468.138277  1342.990074  1392.716129  1403.370510
# 4   1666.350000  1526.341667  1414.246154  1447.910749  1456.301230
# 5   1739.208232  1605.267206  1500.025126  1543.218433  1548.151210
# 6   1744.065833  1608.388309  1491.889744  1522.746425  1564.633333
# 7   1734.204712  1588.002020  1469.147132  1502.133396  1543.155242
# 8   1735.209040  1589.324597  1468.318408  1508.055028  1543.354839
# 9   1773.644167  1638.926931  1514.569231  1554.135693  1586.991649
# 10  1780.519355  1650.838710  1515.558313  1549.533207  1586.917339
# 11  1768.602500  1632.787500  1505.035897  1537.513725  1582.785417
# 12  1773.900082  1635.522177  1511.468983  1560.121673  1591.328629
#
# 구           광진구          구로구          금천구          노원구          도봉구  ...  \
# ...

# %%
# pivot_table 함수를 이용하여 구와 월 컬럼을 이용하여 평균 휘발유 가격을 시각화 하세요 (heatmap 이용)
plt.figure(figsize=(20,10))
# code here
# Out:
# <Axes: xlabel='구', ylabel='월'>

# %%
# pivot_table 함수를 이용하여 구와 월 컬럼을 이용하여 평균 휘발유 가격을 시각화 하세요 (heatmap 이용, 소수점절삭)
plt.figure(figsize=(20,10))
# code here
# Out:
# <Axes: xlabel='구', ylabel='월'>

# %% [markdown]
# ##### 이동평균 구해보기

# %%
# 위에서 구한 mdm_df 월별, 일별로 휘발유의 평균가격에 대해서 라인그래프로 시각화하세요. 
# code here
# Out:
# <Axes: xlabel='월,일'>

# %%
# mdm_df 의 휘발유 컬럼에 대해서 5일 이동 평균을 구해보세요. 
# 데이터프레임(열).rolling(window=일수).mean()
ma5 = # code here 
ma5
# Out:
# 월   일
# 1   1             NaN
#     2             NaN
#     3             NaN
#     4             NaN
#     5     1485.760355
#              ...
# 12  27    1633.115211
#     28    1633.567230
#     29    1634.590046
#     30    1635.063068
#     31    1636.334787
# Name: 휘발유, Length: 365, dtype: float64

# %%
# mdm_df 의 휘발유 컬럼에 대해서 20일 이동 평균을 구해보세요. 

ma20 = # code here 
ma20
# Out:
# 월   일
# 1   1             NaN
#     2             NaN
#     3             NaN
#     4             NaN
#     5             NaN
#              ...
# 12  27    1631.166590
#     28    1631.626630
#     29    1632.071302
#     30    1632.372323
#     31    1632.853204
# Name: 휘발유, Length: 365, dtype: float64

# %%
# mdm_df 의 휘발유 컬럼, 5일 이동평균, 20일 이동평균에 대해서 라인그래프를 그려보세요. 
# figsize=(15,5)
# code here
# Out:
# <Axes: xlabel='월,일'>

# %%
# mdm_df 데이터 프레임에 각각 ma5, ma20, ma60 컬럼을 추가하고, 라인그래프로 시각화하세요. 
# ma60 은 60일 이동평균입니다. figsize=(15,5)

# code here
# Out:
# <Axes: xlabel='월,일'>

# %% [markdown]
# ### 수고하셨습니다.
