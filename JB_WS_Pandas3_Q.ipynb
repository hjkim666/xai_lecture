# %% [markdown]
# ## Pandas 조회 함수, 타입 변경, 정렬 WS

# %%
import pandas as pd

# %% [markdown]
# ### 데이터 불러오기

# %%
# tips_date.csv 파일을 읽어서 df에 저장하세요.
# Out:
#            date  total_bill   tip     sex smoker size
# 0    05-01-2023       21.16  3.00    Male     No  2.0
# 1    05-01-2023       10.07  1.83  Female     No  1.0
# 2    05-01-2023       29.93  5.07    Male     No  4.0
# 3    05-01-2023       12.03  1.50    Male    Yes  2.0
# 4    05-01-2023       34.81  5.20  Female     No  4.0
# ..          ...         ...   ...     ...    ...  ...
# 241  05-06-2023       15.38  3.00  Female    Yes  2.0
# 242  05-06-2023       24.27  2.03    Male    Yes  2.0
# 243  05-06-2023       16.32  4.30  Female    Yes  2.0
# 244  05-06-2023       20.27  2.83  Female     No  2.0
# 245  05-06-2023        7.25  5.15    Male    Yes  2.0
#
# [246 rows x 6 columns]

# %%
# df의 정보를 출력하세요.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        246 non-null    object
#  1   total_bill  246 non-null    float64
#  2   tip         246 non-null    float64
#  3   sex         246 non-null    object
#  4   smoker      246 non-null    object
#  5   size        246 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 11.7+ KB

# %%
# df의 상위 5개 데이터를 출력하세요.
# Out:
#          date  total_bill   tip     sex smoker size
# 0  05-01-2023       21.16  3.00    Male     No  2.0
# 1  05-01-2023       10.07  1.83  Female     No  1.0
# 2  05-01-2023       29.93  5.07    Male     No  4.0
# 3  05-01-2023       12.03  1.50    Male    Yes  2.0
# 4  05-01-2023       34.81  5.20  Female     No  4.0

# %%
# df의 하위 10개 데이터를 출력하세요.
# Out:
#            date  total_bill   tip     sex smoker size
# 236  05-06-2023        5.75  1.00  Female    Yes  2.0
# 237  05-06-2023       34.30  6.70    Male     No  6.0
# 238  05-06-2023       12.46  1.50    Male     No  2.0
# 239  05-06-2023       40.17  4.73    Male    Yes  4.0
# 240  05-06-2023       14.26  2.50    Male     No  2.0
# 241  05-06-2023       15.38  3.00  Female    Yes  2.0
# 242  05-06-2023       24.27  2.03    Male    Yes  2.0
# 243  05-06-2023       16.32  4.30  Female    Yes  2.0
# 244  05-06-2023       20.27  2.83  Female     No  2.0
# 245  05-06-2023        7.25  5.15    Male    Yes  2.0

# %%
# 모든 열의 고윳값의 개수를 출력하세요.
# Out:
# date            6
# total_bill    231
# tip           125
# sex             2
# smoker          2
# size           13
# dtype: int64

# %%
# total_bill, tip을 제외한 나머지 열의 고윳값을 출력하세요. 힌트: isin 함수활용, for문 활용
# Out:
# date:	 ['05-01-2023' '05-02-2023' '05-03-2023' '05-04-2023' '05-05-2023'
#  '05-06-2023']
# sex:	 ['Male' 'Female']
# smoker:	 ['No' 'Yes']
# size:	 ['2.0' '1.0' '4.0' '5.0' '3.0' '4,0' '6.0' '1,0' ' ' '-' '2,0' '2..0'
#  '3,0']

# %%
# total_bill, tip을 제외한 나머지 열의 고윳값 별 데이터 수를 출력하세요. isin 함수 활용.for문 활용. 열별 빈도
# Out:
# 05-01-2023    41
# 05-02-2023    41
# 05-03-2023    41
# 05-04-2023    41
# 05-05-2023    41
# 05-06-2023    41
# Name: date, dtype: int64
# Male      158
# Female     88
# Name: sex, dtype: int64
# No     151
# Yes     95
# Name: smoker, dtype: int64
# 2.0     148
# 3.0      37
# 4.0      36
# 2,0       7
# 5.0       5
# 6.0       4
# 1.0       3
# 4,0       1
# 1,0       1
#           1
# -         1
# 2..0      1
# 3,0       1
# Name: size, dtype: int64

# %%
# total_bill, tip을 제외한 나머지 열의 고윳값 별 데이터 비율을 출력하세요.
# Out:
# 05-01-2023    0.166667
# 05-02-2023    0.166667
# 05-03-2023    0.166667
# 05-04-2023    0.166667
# 05-05-2023    0.166667
# 05-06-2023    0.166667
# Name: date, dtype: float64
# Male      0.642276
# Female    0.357724
# Name: sex, dtype: float64
# No     0.613821
# Yes    0.386179
# Name: smoker, dtype: float64
# 2.0     0.601626
# 3.0     0.150407
# 4.0     0.146341
# 2,0     0.028455
# 5.0     0.020325
# 6.0     0.016260
# 1.0     0.012195
# 4,0     0.004065
# 1,0     0.004065
#         0.004065
# -       0.004065
# 2..0    0.004065
# 3,0     0.004065
# Name: size, dtype: float64

# %%
# df의 열 별 데이터 타입을 조회하세요.
# Out:
# date           object
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# size           object
# dtype: object

# %%
# size 열의 데이터 타입을 float32로 변경하세요.
# 오류가 발생하는 경우 오류의 원인을 찾아서 해결하세요.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 # size 열의 데이터 타입을 float32로 변경하세요.
#       2 # 오류가 발생하는 경우 오류의 원인을 찾아서 해결하세요.
# ----> 3 df['size'] = df['size'].astype('float32')
#       4 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
# Out:
# 0      2.0
# 1      1.0
# 2      4.0
# 3      2.0
# 4      4.0
#       ...
# 241    2.0
# 242    2.0
# 243    2.0
# 244    2.0
# 245    2.0
# Name: size, Length: 246, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 df['size'] = df['size'].astype('float32')
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df['size'] = pd.to_numeric(df['size'])
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
# Out:
# 0      2.0
# 1      1.0
# 2      4.0
# 3      2.0
# 4      4.0
#       ...
# 241    2.0
# 242    2.0
# 243    2.0
# 244    2.0
# 245    2.0
# Name: size, Length: 246, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "-"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 df['size'] = pd.to_numeric(df['size'])
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
# Out:
# 0      2.0
# 1      1.0
# 2      4.0
# 3      2.0
# 4      4.0
#       ...
# 241    2.0
# 242    2.0
# 243    2.0
# 244    2.0
# 245    2.0
# Name: size, Length: 246, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2..0"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 df['size'] = pd.to_numeric(df['size'])
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# ...

# %%
# Out:
# 0      2.0
# 1      1.0
# 2      4.0
# 3      2.0
# 4      4.0
#       ...
# 241    2.0
# 242    2.0
# 243    2.0
# 244    2.0
# 245    2.0
# Name: size, Length: 246, dtype: object

# %%
# Out:
#            date  total_bill   tip     sex smoker  size
# 0    05-01-2023       21.16  3.00    Male     No   2.0
# 1    05-01-2023       10.07  1.83  Female     No   1.0
# 2    05-01-2023       29.93  5.07    Male     No   4.0
# 3    05-01-2023       12.03  1.50    Male    Yes   2.0
# 4    05-01-2023       34.81  5.20  Female     No   4.0
# ..          ...         ...   ...     ...    ...   ...
# 241  05-06-2023       15.38  3.00  Female    Yes   2.0
# 242  05-06-2023       24.27  2.03    Male    Yes   2.0
# 243  05-06-2023       16.32  4.30  Female    Yes   2.0
# 244  05-06-2023       20.27  2.83  Female     No   2.0
# 245  05-06-2023        7.25  5.15    Male    Yes   2.0
#
# [246 rows x 6 columns]

# %%
# size의 데이터 타입을 조회하세요.
# Out:
# dtype('float64')

# %%
# date 열의 데이터 타입을 조회하세요.
# Out:
# dtype('O')

# %%
# date 열의 데이터 타입을 datetime64로 변경하세요.
# Out:
#           date  total_bill   tip     sex smoker  size
# 0   2023-05-01       21.16  3.00    Male     No   2.0
# 1   2023-05-01       10.07  1.83  Female     No   1.0
# 2   2023-05-01       29.93  5.07    Male     No   4.0
# 3   2023-05-01       12.03  1.50    Male    Yes   2.0
# 4   2023-05-01       34.81  5.20  Female     No   4.0
# ..         ...         ...   ...     ...    ...   ...
# 241 2023-05-06       15.38  3.00  Female    Yes   2.0
# 242 2023-05-06       24.27  2.03    Male    Yes   2.0
# 243 2023-05-06       16.32  4.30  Female    Yes   2.0
# 244 2023-05-06       20.27  2.83  Female     No   2.0
# 245 2023-05-06        7.25  5.15    Male    Yes   2.0
#
# [246 rows x 6 columns]

# %%
# df의 열 별 데이터 타입을 조회하세요.
# Out:
# date          datetime64[ns]
# total_bill           float64
# tip                  float64
# sex                   object
# smoker                object
# size                 float64
# dtype: object

# %%
# date 열의 년월일 값을 추출하여 새 열 year, month, day를 생성하세요.
# Out:
#           date  total_bill   tip     sex smoker  size  year  month  day
# 0   2023-05-01       21.16  3.00    Male     No   2.0  2023      5    1
# 1   2023-05-01       10.07  1.83  Female     No   1.0  2023      5    1
# 2   2023-05-01       29.93  5.07    Male     No   4.0  2023      5    1
# 3   2023-05-01       12.03  1.50    Male    Yes   2.0  2023      5    1
# 4   2023-05-01       34.81  5.20  Female     No   4.0  2023      5    1
# ..         ...         ...   ...     ...    ...   ...   ...    ...  ...
# 241 2023-05-06       15.38  3.00  Female    Yes   2.0  2023      5    6
# 242 2023-05-06       24.27  2.03    Male    Yes   2.0  2023      5    6
# 243 2023-05-06       16.32  4.30  Female    Yes   2.0  2023      5    6
# 244 2023-05-06       20.27  2.83  Female     No   2.0  2023      5    6
# 245 2023-05-06        7.25  5.15    Male    Yes   2.0  2023      5    6
#
# [246 rows x 9 columns]

# %%
# year, month, day 열을 이용하여 datetime64 타입의 열 date2를 생성하세요.
# Out:
#           date  total_bill   tip     sex smoker  size  year  month  day  \
# 0   2023-05-01       21.16  3.00    Male     No   2.0  2023      5    1
# 1   2023-05-01       10.07  1.83  Female     No   1.0  2023      5    1
# 2   2023-05-01       29.93  5.07    Male     No   4.0  2023      5    1
# 3   2023-05-01       12.03  1.50    Male    Yes   2.0  2023      5    1
# 4   2023-05-01       34.81  5.20  Female     No   4.0  2023      5    1
# ..         ...         ...   ...     ...    ...   ...   ...    ...  ...
# 241 2023-05-06       15.38  3.00  Female    Yes   2.0  2023      5    6
# 242 2023-05-06       24.27  2.03    Male    Yes   2.0  2023      5    6
# 243 2023-05-06       16.32  4.30  Female    Yes   2.0  2023      5    6
# 244 2023-05-06       20.27  2.83  Female     No   2.0  2023      5    6
# 245 2023-05-06        7.25  5.15    Male    Yes   2.0  2023      5    6
#
#          date2
# 0   2023-05-01
# 1   2023-05-01
# 2   2023-05-01
# 3   2023-05-01
# 4   2023-05-01
# ...

# %%
# df의 열 별 데이터 타입을 조회하세요.
# Out:
# date          datetime64[ns]
# total_bill           float64
# tip                  float64
# sex                   object
# smoker                object
# size                 float64
# year                   int64
# month                  int64
# day                    int64
# date2         datetime64[ns]
# dtype: object

# %%
# date2 열을 삭제하세요.
# Out:
#           date  total_bill   tip     sex smoker  size  year  month  day
# 0   2023-05-01       21.16  3.00    Male     No   2.0  2023      5    1
# 1   2023-05-01       10.07  1.83  Female     No   1.0  2023      5    1
# 2   2023-05-01       29.93  5.07    Male     No   4.0  2023      5    1
# 3   2023-05-01       12.03  1.50    Male    Yes   2.0  2023      5    1
# 4   2023-05-01       34.81  5.20  Female     No   4.0  2023      5    1
# ..         ...         ...   ...     ...    ...   ...   ...    ...  ...
# 241 2023-05-06       15.38  3.00  Female    Yes   2.0  2023      5    6
# 242 2023-05-06       24.27  2.03    Male    Yes   2.0  2023      5    6
# 243 2023-05-06       16.32  4.30  Female    Yes   2.0  2023      5    6
# 244 2023-05-06       20.27  2.83  Female     No   2.0  2023      5    6
# 245 2023-05-06        7.25  5.15    Male    Yes   2.0  2023      5    6
#
# [246 rows x 9 columns]

# %%
# 5월 3일의 데이터만 추출하세요.
# Out:
#           date  total_bill   tip     sex smoker  size  year  month  day
# 82  2023-05-03       20.29  2.75  Female     No   2.0  2023      5    3
# 83  2023-05-03       30.46  2.00    Male    Yes   5.0  2023      5    3
# 84  2023-05-03       17.47  3.50  Female     No   2.0  2023      5    3
# 85  2023-05-03       17.46  2.54    Male     No   2.0  2023      5    3
# 86  2023-05-03       28.44  2.56    Male    Yes   2.0  2023      5    3
# 87  2023-05-03       15.69  3.00    Male    Yes   3.0  2023      5    3
# 88  2023-05-03       12.76  2.23  Female    Yes   2.0  2023      5    3
# 89  2023-05-03       35.83  4.67  Female     No   3.0  2023      5    3
# 90  2023-05-03       32.90  3.11    Male    Yes   2.0  2023      5    3
# 91  2023-05-03       34.63  3.55    Male    Yes   2.0  2023      5    3
# 92  2023-05-03       11.87  1.63  Female     No   2.0  2023      5    3
# 93  2023-05-03       23.95  2.55    Male     No   2.0  2023      5    3
# ...

# %%
# date 열을 인덱스로 지정하세요. set_index()
# Out:
#             total_bill   tip     sex smoker  size  year  month  day
# date
# 2023-05-01       21.16  3.00    Male     No   2.0  2023      5    1
# 2023-05-01       10.07  1.83  Female     No   1.0  2023      5    1
# 2023-05-01       29.93  5.07    Male     No   4.0  2023      5    1
# 2023-05-01       12.03  1.50    Male    Yes   2.0  2023      5    1
# 2023-05-01       34.81  5.20  Female     No   4.0  2023      5    1
# ...                ...   ...     ...    ...   ...   ...    ...  ...
# 2023-05-06       15.38  3.00  Female    Yes   2.0  2023      5    6
# 2023-05-06       24.27  2.03    Male    Yes   2.0  2023      5    6
# 2023-05-06       16.32  4.30  Female    Yes   2.0  2023      5    6
# 2023-05-06       20.27  2.83  Female     No   2.0  2023      5    6
# 2023-05-06        7.25  5.15    Male    Yes   2.0  2023      5    6
#
# [246 rows x 8 columns]

# %%
# 5월 3일의 데이터만 추출하세요.  날짜인덱스활용
# Out:
#             total_bill   tip     sex smoker  size  year  month  day
# date
# 2023-05-03       20.29  2.75  Female     No   2.0  2023      5    3
# 2023-05-03       30.46  2.00    Male    Yes   5.0  2023      5    3
# 2023-05-03       17.47  3.50  Female     No   2.0  2023      5    3
# 2023-05-03       17.46  2.54    Male     No   2.0  2023      5    3
# 2023-05-03       28.44  2.56    Male    Yes   2.0  2023      5    3
# 2023-05-03       15.69  3.00    Male    Yes   3.0  2023      5    3
# 2023-05-03       12.76  2.23  Female    Yes   2.0  2023      5    3
# 2023-05-03       35.83  4.67  Female     No   3.0  2023      5    3
# 2023-05-03       32.90  3.11    Male    Yes   2.0  2023      5    3
# 2023-05-03       34.63  3.55    Male    Yes   2.0  2023      5    3
# 2023-05-03       11.87  1.63  Female     No   2.0  2023      5    3
# 2023-05-03       23.95  2.55    Male     No   2.0  2023      5    3
# 2023-05-03        7.74  1.44    Male    Yes   2.0  2023      5    3
# ...

# %%
# index를 다시 정수로 초기화하세요.  reset_index()
# Out:
#           date  total_bill   tip     sex smoker  size  year  month  day
# 0   2023-05-01       21.16  3.00    Male     No   2.0  2023      5    1
# 1   2023-05-01       10.07  1.83  Female     No   1.0  2023      5    1
# 2   2023-05-01       29.93  5.07    Male     No   4.0  2023      5    1
# 3   2023-05-01       12.03  1.50    Male    Yes   2.0  2023      5    1
# 4   2023-05-01       34.81  5.20  Female     No   4.0  2023      5    1
# ..         ...         ...   ...     ...    ...   ...   ...    ...  ...
# 241 2023-05-06       15.38  3.00  Female    Yes   2.0  2023      5    6
# 242 2023-05-06       24.27  2.03    Male    Yes   2.0  2023      5    6
# 243 2023-05-06       16.32  4.30  Female    Yes   2.0  2023      5    6
# 244 2023-05-06       20.27  2.83  Female     No   2.0  2023      5    6
# 245 2023-05-06        7.25  5.15    Male    Yes   2.0  2023      5    6
#
# [246 rows x 9 columns]

# %%
# total_bill 값이 높은 순서대로 데이터를 정렬하세요.
# Out:
#           date  total_bill    tip     sex smoker  size  year  month  day
# 220 2023-05-06       50.81  10.00    Male    Yes   3.0  2023      5    6
# 38  2023-05-01       48.33   9.00    Male     No   4.0  2023      5    1
# 35  2023-05-01       48.27   6.73    Male     No   4.0  2023      5    1
# 39  2023-05-01       48.17   5.00    Male     No   6.0  2023      5    1
# 218 2023-05-06       45.35   3.50    Male    Yes   3.0  2023      5    6
# ..         ...         ...    ...     ...    ...   ...   ...    ...  ...
# 232 2023-05-06        7.51   2.00    Male     No   2.0  2023      5    6
# 124 2023-05-04        7.25   1.00  Female     No   1.0  2023      5    4
# 245 2023-05-06        7.25   5.15    Male    Yes   2.0  2023      5    6
# 236 2023-05-06        5.75   1.00  Female    Yes   2.0  2023      5    6
# 72  2023-05-02        3.07   1.00  Female    Yes   1.0  2023      5    2
#
# [246 rows x 9 columns]

# %%
# size (방문 인원) 수가 적은 순서대로 데이터를 정렬하세요.
# Out:
#           date  total_bill   tip     sex smoker  size  year  month  day
# 1   2023-05-01       10.07  1.83  Female     No   1.0  2023      5    1
# 28  2023-05-01        8.58  1.92    Male    Yes   1.0  2023      5    1
# 72  2023-05-02        3.07  1.00  Female    Yes   1.0  2023      5    2
# 124 2023-05-04        7.25  1.00  Female     No   1.0  2023      5    4
# 0   2023-05-01       21.16  3.00    Male     No   2.0  2023      5    1
# ..         ...         ...   ...     ...    ...   ...   ...    ...  ...
# 19  2023-05-01       29.80  4.20  Female     No   6.0  2023      5    1
# 237 2023-05-06       34.30  6.70    Male     No   6.0  2023      5    6
# 39  2023-05-01       48.17  5.00    Male     No   6.0  2023      5    1
# 41  2023-05-02       25.34  4.66    Male    Yes   NaN  2023      5    2
# 49  2023-05-02       12.13  2.87  Female    Yes   NaN  2023      5    2
#
# [246 rows x 9 columns]

# %%
# 성별과 tip 순으로 데이터를 정렬하되, 성별은 오름차순, tip은 내림차순으로 정렬하세요. 
# 힌트: 여러개 정렬조건 [열1, 열2], acsending=[오름차순, 내림차순]
# Out:
#           date  total_bill   tip     sex smoker  size  year  month  day
# 153 2023-05-04       28.17  6.50  Female    Yes   3.0  2023      5    4
# 4   2023-05-01       34.81  5.20  Female     No   4.0  2023      5    1
# 127 2023-05-04       34.83  5.17  Female     No   4.0  2023      5    4
# 200 2023-05-05       29.85  5.14  Female     No   5.0  2023      5    5
# 63  2023-05-02       35.26  5.00  Female     No   4.0  2023      5    2
# ..         ...         ...   ...     ...    ...   ...   ...    ...  ...
# 150 2023-05-04        9.68  1.32    Male     No   2.0  2023      5    4
# 37  2023-05-01       10.51  1.25    Male     No   2.0  2023      5    1
# 57  2023-05-02       10.07  1.25    Male     No   2.0  2023      5    2
# 173 2023-05-05       32.83  1.17    Male    Yes   2.0  2023      5    5
# 48  2023-05-02       12.60  1.00    Male    Yes   2.0  2023      5    2
#
# [246 rows x 9 columns]

# %%
# tip을 가장 많이 지불한 고객 상위 10명의 데이터를 출력하세요.
# Out:
#           date  total_bill    tip     sex smoker  size  year  month  day
# 220 2023-05-06       50.81  10.00    Male    Yes   3.0  2023      5    6
# 38  2023-05-01       48.33   9.00    Male     No   4.0  2023      5    1
# 10  2023-05-01       39.42   7.58    Male     No   4.0  2023      5    1
# 35  2023-05-01       48.27   6.73    Male     No   4.0  2023      5    1
# 237 2023-05-06       34.30   6.70    Male     No   6.0  2023      5    6
# 153 2023-05-04       28.17   6.50  Female    Yes   3.0  2023      5    4
# 11  2023-05-01       23.17   6.50    Male    Yes   4.0  2023      5    1
# 184 2023-05-05       32.40   6.00    Male     No   4.0  2023      5    5
# 9   2023-05-01       29.03   5.92    Male     No   3.0  2023      5    1
# 151 2023-05-04       24.71   5.85    Male     No   2.0  2023      5    4

# %%
# total_bill과 tip의 합계 금액이 가장 낮은 고객 10명의 데이터를 출력하세요.
# Out:
#           date  total_bill   tip     sex smoker  size  year  month  day
# 72  2023-05-02        3.07  1.00  Female    Yes   1.0  2023      5    2
# 236 2023-05-06        5.75  1.00  Female    Yes   2.0  2023      5    6
# 124 2023-05-04        7.25  1.00  Female     No   1.0  2023      5    4
# 31  2023-05-01        7.56  1.44    Male     No   2.0  2023      5    1
# 94  2023-05-03        7.74  1.44    Male    Yes   2.0  2023      5    3
# 232 2023-05-06        7.51  2.00    Male     No   2.0  2023      5    6
# 163 2023-05-04        8.51  1.25  Female     No   2.0  2023      5    4
# 113 2023-05-03        8.35  1.50  Female     No   2.0  2023      5    3
# 213 2023-05-06        8.52  1.48    Male     No   2.0  2023      5    6
# 28  2023-05-01        8.58  1.92    Male    Yes   1.0  2023      5    1

# %%
# 흡연자 중 tip을 가장 많이 지불한 상위 10명의 데이터를 추출하세요.
# Out:
#           date  total_bill    tip     sex smoker  size  year  month  day
# 220 2023-05-06       50.81  10.00    Male    Yes   3.0  2023      5    6
# 153 2023-05-04       28.17   6.50  Female    Yes   3.0  2023      5    4
# 11  2023-05-01       23.17   6.50    Male    Yes   4.0  2023      5    1
# 102 2023-05-03       23.33   5.65    Male    Yes   2.0  2023      5    3
# 148 2023-05-04       25.89   5.16    Male    Yes   4.0  2023      5    4
# ..         ...         ...    ...     ...    ...   ...   ...    ...  ...
# 173 2023-05-05       32.83   1.17    Male    Yes   2.0  2023      5    5
# 66  2023-05-02       12.90   1.10  Female    Yes   2.0  2023      5    2
# 236 2023-05-06        5.75   1.00  Female    Yes   2.0  2023      5    6
# 48  2023-05-02       12.60   1.00    Male    Yes   2.0  2023      5    2
# 72  2023-05-02        3.07   1.00  Female    Yes   1.0  2023      5    2
#
# [95 rows x 9 columns]

# %%
# total_bill이 높은 상위 20명의 남녀 수를 출력하세요.
# Out:
# Male      14
# Female     6
# Name: sex, dtype: int64

# %%
# tip이 낮은 하위 20명의 방문 날짜 비율을 출력하세요.
# 날짜 순으로 정렬하세요.
# Out:
# 1    0.20
# 2    0.25
# 3    0.05
# 4    0.20
# 5    0.15
# 6    0.15
# Name: day, dtype: float64

# %%
# total_bill 대비 tip의 비율이 높은 상위 10명의 흡연자 비율을 출력하세요.
# Out:
# Yes    0.7
# No     0.3
# Name: smoker, dtype: float64

# %%
# size는 방문 고객의 그룹 인원입니다.
# total_bill은 해당 방문 고객들이 지출한 식사 비용입니다.
# 1인 당 지출한 평균 금액이 적은 순서대로 데이터를 정렬하세요.
# Out:
#           date  total_bill    tip     sex smoker  size  year  month  day
# 236 2023-05-06        5.75   1.00  Female    Yes   2.0  2023      5    6
# 72  2023-05-02        3.07   1.00  Female    Yes   1.0  2023      5    2
# 185 2023-05-05       10.33   1.67  Female     No   3.0  2023      5    5
# 103 2023-05-03       10.34   1.66    Male     No   3.0  2023      5    3
# 245 2023-05-06        7.25   5.15    Male    Yes   2.0  2023      5    6
# ..         ...         ...    ...     ...    ...   ...   ...    ...  ...
# 220 2023-05-06       50.81  10.00    Male    Yes   3.0  2023      5    6
# 91  2023-05-03       34.63   3.55    Male    Yes   2.0  2023      5    3
# 34  2023-05-01       40.55   3.00    Male    Yes   2.0  2023      5    1
# 41  2023-05-02       25.34   4.66    Male    Yes   NaN  2023      5    2
# 49  2023-05-02       12.13   2.87  Female    Yes   NaN  2023      5    2
#
# [246 rows x 9 columns]

# %%
# 5월 1일에 방문한 고객 중 여성 고객의 데이터를 tip 금액을 기준으로 내림차순 정렬하세요.
# Out:
#          date  total_bill   tip     sex smoker  size  year  month  day
# 4  2023-05-01       34.81  5.20  Female     No   4.0  2023      5    1
# 19 2023-05-01       29.80  4.20  Female     No   6.0  2023      5    1
# 26 2023-05-01       20.92  4.08  Female     No   2.0  2023      5    1
# 40 2023-05-01       17.31  3.50  Female     No   2.0  2023      5    1
# 15 2023-05-01       13.42  3.48  Female    Yes   2.0  2023      5    1
# 21 2023-05-01       16.47  3.23  Female    Yes   3.0  2023      5    1
# 32 2023-05-01       15.98  3.00  Female     No   3.0  2023      5    1
# 7  2023-05-01       14.52  2.00  Female     No   2.0  2023      5    1
# 13 2023-05-01       13.00  2.00  Female    Yes   2.0  2023      5    1
# 20 2023-05-01       10.63  2.00  Female    Yes   2.0  2023      5    1
# 1  2023-05-01       10.07  1.83  Female     No   1.0  2023      5    1
# 22 2023-05-01       18.64  1.36  Female     No   3.0  2023      5    1

# %%
# 5월 6일에 방문한 고객 중 남성 고객의 데이터를 
# 흡연자, size, total_bill을 기준으로 각각 내림, 오름, 내림차순으로 정렬하세요.
# 정렬한 결과의 인덱스를 초기화(reset_index)한 후 df2에 저장한 후 출력하세요.
# Out:
#          date  total_bill    tip   sex smoker  size  year  month  day
# 0  2023-05-06       25.21   4.29  Male    Yes   2.0  2023      5    6
# 1  2023-05-06       24.27   2.03  Male    Yes   2.0  2023      5    6
# 2  2023-05-06       22.67   2.00  Male    Yes   2.0  2023      5    6
# 3  2023-05-06        7.25   5.15  Male    Yes   2.0  2023      5    6
# 4  2023-05-06       50.81  10.00  Male    Yes   3.0  2023      5    6
# 5  2023-05-06       45.35   3.50  Male    Yes   3.0  2023      5    6
# 6  2023-05-06       40.17   4.73  Male    Yes   4.0  2023      5    6
# 7  2023-05-06       22.49   3.50  Male     No   2.0  2023      5    6
# 8  2023-05-06       21.70   4.30  Male     No   2.0  2023      5    6
# 9  2023-05-06       14.26   2.50  Male     No   2.0  2023      5    6
# 10 2023-05-06       13.94   3.06  Male     No   2.0  2023      5    6
# 11 2023-05-06       12.54   2.50  Male     No   2.0  2023      5    6
# ...
